# %% [markdown]
# # Optimizing neurally diverse architectures for small and imbalanced subsets of MNIST
#
# * This notebook is for exploring architectural specifications for neurally diverse architectures on a small and imbalanced version of MNIST.
# * The architecture includes pre-branch, branch, and post-branch segments. Neural diversity is implemented specifically at the level of activation function non-linearity and a small wet of "connection functions" (i.e. linear, identity, and element-wise scaling).
# * A highly simplistic form of architectural search based on stochastic hill-climbing with some differential search is included, for your reference.
# * 0.3.7 - added id and elementwise scaling weight functions.
# * 0.3.8 - added training acuracies; do_train is now returning the model with the best validation error.
# * 0.3.9 - added basic DropCircuit.

# %%
version = '_v0p3p9_'

import time
import warnings
import random
import pdb

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
from sklearn.utils import shuffle

import torch
import numpy as np
from torch.utils import data
import copy

from __future__ import print_function
import argparse
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from IPython.core.debugger import set_trace

# ===============
# Initializations
# ===============

# !pip install torch torchvision

# ===============
# Parameters
# ===============

# --- General framework arguments

args = {}
kwargs = {}
args['num_train_batch'] = 1  # number of MNIST training batches
args['num_valid_batch'] = 10  # number of MNIST validation batches
args['train_batch_size'] = 100   # training batch size
args['valid_batch_size'] = 100   # validation batch size
args['test_batch_size'] = 10
# args['epochs'] = 100  # number of training epochs
args['lr'] = 1 # 0.1  # 0.01 # learning rate # this is over-written by the solution
args['momentum'] = 0.5 # SGD momentum (default: 0.5); momentum is a moving average of our gradients (helps keep a useful direction)
args['clip_level'] = 0.5  # gradient clip threshold
args['seed']= 1 #random seed
args['log_interval_epoch'] = 1 # display training loss every log_int... epochs
args['cuda'] = True
args['patience'] = 1000  # stop train. if the valid. err. hasn't improved by this num. of epochs
args['noise_in'] = -1   # 0.5  # 0.15  # amount of noise to add to the training data
args['noise_out'] = -1   #  probability of changing an output label to some random label
args['verbose_train'] = False   # print status of model training?
args['verbose_meta'] = True #  print status of architecture optimization?
args['min_inst_class'] = 5 # minimum number of instances per class in the training set
args['batch_max_tries'] = 10 # max. num. of attempts in extracting data batches
args['save_best_chrom'] = True # False  # save the best chromose in Google Drive?
args['dc_prob_drop'] = 0.5 # 0.5 # probability of dropping a circuit (DropCircuit)
args['prob_sel_branch'] = 0.5 # probability of architectural search selecting/using a branch (this is not DropCircuit)

# --- Neural architectural limits

args['num_epochs_search'] = 10 # 100  # number of epochs for training during architecture search
args['num_epochs_test'] = 1000  # num. epochs for training during the final test
limits = {}
limits['min_layer_nodes'] =  10 # 5 # 50
limits['max_layer_nodes'] = 100
limits['max_pre_branch_layers'] = 5 # 3
limits['max_branches'] = 10
limits['max_branch_layers'] = 5  # 3
limits['max_post_branch_layers'] = 5 # 3
limits['lr1_min'] = 0.001
limits['lr1_,max'] = 2
limits['lr2_min'] = 0.001
limits['lr2_,max'] = 2
limits['moment_min'] = 0.001
limits['moment_max'] = 1

# np.random.seed(0)
# torch.manual_seed(0)

num_train_instances = args['num_train_batch'] * args['train_batch_size']
num_valid_instances = args['num_valid_batch'] * args['valid_batch_size']

data_rand_seed = 1 # (other pre-tested seeds: 2, 3)

# ============
# Load dataset
# ============

# Seed creation
torch.manual_seed(data_rand_seed)
np.random.seed(data_rand_seed)

a_data_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=a_data_transform),
    batch_size=args['train_batch_size'], shuffle=True, **kwargs)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=a_data_transform),
    batch_size=args['test_batch_size'], shuffle=True, **kwargs)

# Check whether we have enough instances per class
# We want an imbalanced dataset but we don't want any specific label having
# an "insufficient" number of instances.
def check_enough_inst(batches, min_inst_per_class):

  # Concatenate training batch output labels
  labels = batches[0][1].numpy()
  for batch_i in range(1,args['num_train_batch']):
    new_labels = batches[batch_i][1].numpy()
    labels = np.concatenate((labels, new_labels))

  labels = labels.tolist()

  # Scan though labels
  for a_label in range(10):  # assuming MNIST, of course
    a_count = labels.count(a_label)
    # If label count is < min_inst_per_class return False
    if a_count < min_inst_per_class:
      return False

  # Return True
  return True


# Prepare data. Extract training and validation batches
# This is where we make the problem "small and imbalanced"
def extract_batches(a_loader, min_inst_per_class, max_tries):

  # Keep trying until you have a required minimum number of instances
  # per class in the training set (not elegant but ok for the range of
  # "min_inst_per_class" we need)

  for ti in range(max_tries):

    print('Data extraction trial {}.'.format(ti))

    # Initializations
    train_batches = []
    valid_batches = []
    tot_batch_extract = args['num_train_batch'] + args['num_valid_batch']

    # Extract
    for batch_idx, (data, target) in enumerate(a_loader):

      if batch_idx < args['num_train_batch']:
        train_batches.append((data,target))
      else:
        valid_batches.append((data,target))
        if batch_idx == tot_batch_extract - 1:
          break

    # Check minimum number of instances
    enough_instaces = check_enough_inst(train_batches, min_inst_per_class)
    if enough_instaces:
      return train_batches, valid_batches

  print('It was not possible to create a dataset.')
  print('Consider increasing the overall number of instances, or')
  print('decreasing the minimum instances per class allowed.')
  return [], []


train_batches, valid_batches = extract_batches(train_loader, args['min_inst_class'], args['batch_max_tries'])
if args['verbose_train']:
  print('Extracted {} train_batches, and {} valid_batches.'.format(len(train_batches), len(valid_batches)))

# ===========================
# Display histogram of labels
# ===========================

def disp_hist_labaels(batches):
  # Concatenate training batch output labels
  labels = batches[0][1].numpy()
  for batch_i in range(1,args['num_train_batch']):
    new_labels = batches[batch_i][1].numpy()
    labels = np.concatenate((labels, new_labels))

  num_bins = 10
  n, bins, patches = plt.hist(labels, num_bins, facecolor='blue', alpha=0.5)
  plt.show()

disp_hist_labaels(train_batches)

# ==========================
# Display dataset
# ==========================

# This is not currently used

# Display MNIST instances
# Adapted from # https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/pytorch-mnist-mlp.ipynb
def disp_MNIST_inst(num_disp, X_train, y_train):
  pltsize=1
  plt.figure(figsize=(num_disp*pltsize, pltsize))
  for i in range(num_disp):
    plt.subplot(1,num_disp,i+1)
    plt.axis('off')
    plt.imshow(X_train[i,:,:].numpy().reshape(28,28), cmap="gray_r")
    plt.title('Class: '+str(y_train[i].item()))

if args['verbose_train']:
  X_train = train_batches[0][0]
  y_train = train_batches[0][1]

  disp_MNIST_inst(10, X_train, y_train)

  sum_train_0 = X_train[0,:,:].sum()
  min_train_0 = X_train[0,:,:].min()
  max_train_0 = X_train[0,:,:].max()

  print('X_train[0,:,:] --> sum ({}); min ({}); max ({}).'.format(sum_train_0, min_train_0, max_train_0))

# ==========================
# Design model
# ==========================

# "Unseed" the rest
np.random.seed()
a_rand_seed = np.random.randint(0,999999)
torch.manual_seed(a_rand_seed)

# Simple function to scale parameters
# num is assume to be \in [0,1]
def scale_to_range(num,min_val,max_val):
  range = max_val - min_val
  return (num*range)+min_val

# Simple layer for doing elementwise scaling
# Adapated from https://stackoverflow.com/questions/51980654/pytorch-element-wise-filter-layer
class Elem_Scaling_1D(nn.Module):
  def __init__(self, num_nodes, bogus):  # clean-up "bogus"
    super(Elem_Scaling_1D, self).__init__()
    # Initialize
    init_weights = np.random.normal(loc=0, scale=0.5, size=np.shape(num_nodes))
    # Assign
    self.weights = torch.from_numpy(init_weights)
    #self.weights = nn.Parameter(torch.Tensor(1, num_nodes))  # trainable parameter

  def forward(self, x):
    # assuming x is of size num_inst-1-num_nodes
    return x * self.weights  # element-wise multiplication

# Class gradient-based neural diversity machine
class GBNDM(nn.Module):
    def __init__(self, a_chromosome):   # assuming MNIST
        super(GBNDM, self).__init__()

        # --------- Pre-branch layers
        self.chromosome = a_chromosome
        self.pre_branch_layers = nn.ModuleList()
        prev_num_out = 28*28
        chrom_ind = 5 # skip over 3 learning rate param., 1 moment. p. (interp./used in training)
        # and 1 exist-or-not (may use in future versions).
        # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
        for i in range(limits['max_pre_branch_layers']):

          # Extract and interpret parameters
          layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
          layer_params_real = self.interp_layer_param(layer_params_raw)

          # Decide on whether to create a layer or not
          if i==0:  # the first layer of each segment is done by default
            do_layer = True
          else:
            do_layer = layer_params_real[0]

          if do_layer:
            # Create layer
            a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
            # Append layer and update chromosome index
            self.pre_branch_layers.append(a_layer)

          chrom_ind += 6

        # --------- Branches
        num_out_pre_branch = prev_num_out

        self.branches = nn.ModuleList()

        # Scan over branches
        final_num_nodes = []  # keep track of the size of the final layer of each branch
        count_branches = 0
        for bi in range(limits['max_branches']):

          # Initialize branch
          branch_layers = nn.ModuleList()

          # Do branch? Always do the first one by default
          if (a_chromosome[chrom_ind] < args['prob_sel_branch']) or (bi == 0):
            do_branch = True
          else:
            do_branch = False

          chrom_ind += 1

          # Scan over branch layers

          if do_branch:  # if doing branch

            this_fin_num_nodes = 0

            count_branches += 1

            for li in range(limits['max_branch_layers']):

              # Extract and interpret parameters
              layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
              layer_params_real = self.interp_layer_param(layer_params_raw)

              # Decide on whether to create a layer or not
              if li==0:  # the first layer of each branch is done by default
                do_layer = True
                prev_num_out = num_out_pre_branch
              else:
                do_layer = layer_params_real[0]

              if do_layer:
                # print('... temp ... this_fin_num_nodes: {}.'.format(this_fin_num_nodes))
                # Create layer
                a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
                # Num_nodes - keep storing the latest one; the last latest is the final layer num_nodes
                this_fin_num_nodes = prev_num_out
                # Append layer and update chromosome index
                branch_layers.append(a_layer)

              chrom_ind += 6

            # Append branch
            final_num_nodes.append(this_fin_num_nodes)
            #print('final_num_nodes: {}.'.format(final_num_nodes))
            self.branches.append(branch_layers)

          else: # if not doing branch you still need to increment chromosome index

            chrom_ind += 6*limits['max_branch_layers']

        self.num_branches = count_branches
        self.dc_prob_activ = 1 - args['dc_prob_drop'] # probability of using a circuit
        self.tot_nodes_branch_final = sum(final_num_nodes)

        # --------- Post-branch layers

        prev_num_out = self.tot_nodes_branch_final

        # --- Create post-branch layers

        chrom_ind += 1  # skip over the parameter pertaining to the existence or not of the post-branch segment

        self.post_branch_layers = nn.ModuleList()

        # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
        for li in range(limits['max_post_branch_layers']):

          # Extract and interpret parameters
          layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
          layer_params_real = self.interp_layer_param(layer_params_raw)

          # Decide on whether to create a layer or not
          if li==0:  # the first layer of each segment is done by default
            do_layer = True
          else:
            do_layer = layer_params_real[0]

          if do_layer:
            # Create layer
            a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
            # Append layer and update chromosome index
            self.post_branch_layers.append(a_layer)

          chrom_ind += 6

        # Create a final layer
        self.final_layer = nn.Linear(prev_num_out, 10)

    def forward(self, x, dc_mask = None):

        x = x.view(-1, 28*28)

        # Apply pre-branch layers
        for pi, a_layer in enumerate(self.pre_branch_layers):
          #print('Pre-layer {}'.format(pi))
          # if isinstance(a_layer, Elem_Scaling_1D):
          #   set_trace()
          x = a_layer(x)

        # Apply branches
        branch_finals = []
        for bi, a_branch in enumerate(self.branches):
          #print('Branch {}'.format(bi))

          z = x

          for a_layer in a_branch:
            # if isinstance(a_layer, Elem_Scaling_1D):
            #   set_trace()
            z = a_layer(z)

          if self.training:
            z = (dc_mask[bi] * z) / self.dc_prob_activ  # if training apply DropCircuit

          branch_finals.append(z)

        # Concatenate multi-branch final layers
        x = torch.cat(branch_finals,dim=1)

        # if not(self.training): # if not training then testing/evaluating
        #   x = self.dc_prob_activ * x  # scaling due to DropCircuit


        # Apply post-branch layers
        for pi, a_layer in enumerate(self.post_branch_layers):
          #print('Post-layer: {}'.format(pi))
          # if isinstance(a_layer, Elem_Scaling_1D):
          #   set_trace()
          x = a_layer(x)

        # Apply final layer
        x = self.final_layer(x)

        return F.log_softmax(x, dim=1)


    # Method for interpreting layer parameters
    # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
    def interp_layer_param(self, layer_params_raw):
      # Exist or not
      if layer_params_raw[0] < 0.5:
        exist = False
      else:
        exist = True
      # Weight function
      tot_weight_func = 3
      if layer_params_raw[1] < 0.6: # or ... (1/tot_weight_func):
        weight_func_sel = 'linear'
      elif layer_params_raw[1] < 0.8: # or ... (2/tot_weight_func):
        weight_func_sel = 'elem_scale'
      else:
        weight_func_sel = 'id'
      # activation function
      tot_node_func = 22
      if layer_params_raw[2] < (1/tot_node_func):
        activ_func = 'ReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (2/tot_node_func):
        activ_func = 'Hardshrink'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (3/tot_node_func):
        activ_func = 'Hardtanh'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,2)
        if param_1 > param_2:  # param_1 is min_val; param_2 is max_val
          tmp_val = param_1
          param_1 = param_2
          param_2 = tmp_val
        elif param_1 == param_2:
          param_2 += 0.1
      elif layer_params_raw[2] < (4/tot_node_func):
        activ_func = 'LeakyReLU'
        param_1 = scale_to_range(layer_params_raw[3],0,1)
        param_2 = -1
      elif layer_params_raw[2] < (5/tot_node_func):
        activ_func = 'LogSigmoid'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (6/tot_node_func):
        activ_func = 'PReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (7/tot_node_func):
        activ_func = 'ELU'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (8/tot_node_func):
        activ_func = 'ReLU6'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (9/tot_node_func):
        activ_func = 'RReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (10/tot_node_func):
        activ_func = 'SELU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (11/tot_node_func):
        activ_func = 'CELU'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (12/tot_node_func):
        activ_func = 'GELU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (13/tot_node_func):
        activ_func = 'Sigmoid'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (14/tot_node_func):
        activ_func = 'Softplus'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,40)
      elif layer_params_raw[2] < (15/tot_node_func):
        activ_func = 'Softshrink'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (16/tot_node_func):
        activ_func = 'Softsign'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (17/tot_node_func):
        activ_func = 'Tanh'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (18/tot_node_func):
        activ_func = 'Tanhshrink'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (19/tot_node_func):
        activ_func = 'Threshold'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,2)
      elif layer_params_raw[2] < (20/tot_node_func):
        activ_func = 'Softmin'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (21/tot_node_func):
        activ_func = 'Softmax'
        param_1 = -1
        param_2 = -1
      else:
        activ_func = 'None'
        param_1 = -1
        param_2 = -1

      # number of nodes
      num_nodes = scale_to_range(layer_params_raw[5], limits['min_layer_nodes'], limits['max_layer_nodes'])
      num_nodes = num_nodes.astype(int)

      return (exist, weight_func_sel, activ_func, param_1, param_2, num_nodes)

    # Method for creating a layer
    # layer_params_real format: (exist, weight_func_sel, activ_func, param_1, param_2, num_nodes)
    def create_layer(self, prev_num_out, layer_params_real):

      exist, weight_func_sel, activ_func, param_1, param_2, num_nodes = layer_params_real

      # wf_param1/wf_param2 --> not elegant
      if weight_func_sel == 'linear':
        weight_func = nn.Linear
        num_nodes_in = prev_num_out
        num_nodes_out = num_nodes
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
      elif weight_func_sel == 'id':
        weight_func = nn.Identity
        num_nodes_in = prev_num_out
        num_nodes_out = prev_num_out
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
      else:  # 'elem_scale'
        weight_func = Elem_Scaling_1D
        num_nodes_in = prev_num_out
        num_nodes_out = prev_num_out
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out

      if activ_func == 'ReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU())
      elif activ_func == 'Hardshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Hardshrink(param_1))
      elif activ_func == 'Hardtanh':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Hardtanh(param_1, param_2))
      elif activ_func == 'LeakyReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.LeakyReLU(param_1))
      elif activ_func == 'LogSigmoid':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.LogSigmoid())
      elif activ_func == 'PReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.PReLU())
      elif activ_func == 'ELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ELU(param_1))
      elif activ_func == 'ReLU6':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU6())
      elif activ_func == 'RReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.RReLU())
      elif activ_func == 'SELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.SELU())
      elif activ_func == 'CELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.CELU(param_1))
      elif activ_func == 'GELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU())  # for some reason GELU is not present; revert later if relevant
      elif activ_func == 'Sigmoid':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Sigmoid())
      elif activ_func == 'Softplus':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softplus(param_1, param_2))
      elif activ_func == 'Softshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softplus(param_1))
      elif activ_func == 'Softsign':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softsign())
      elif activ_func == 'Tanh':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Tanh())
      elif activ_func == 'Tanhshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Tanhshrink())
      elif activ_func == 'Threshold':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Threshold(param_1, param_2))
      elif activ_func == 'Softmin':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softmin())
      elif activ_func == 'Softmax':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softmax())
      else:
        a_layer = weight_func(wf_param1, wf_param2)

      return a_layer, num_nodes_out


# Generate a random chromosome where each param. is \in [0,1)
def gen_rand_chromosome(num_param):
  chrom = np.random.rand(num_param)
  return chrom

# ==========================
# Train and test functions
# ==========================

# Create a random mask for DropCircuit
def make_mask(num_circuits, prob_drop):
  rand_vals = np.random.rand(num_circuits)
  decisions = rand_vals >= prob_drop
  a_mask = np.ones(num_circuits)*decisions
  # Must have at least one circuit active
  if np.sum(a_mask) == 0:
    rand_index = np.random.randint(num_circuits)
    a_mask[rand_index] = 1.0

  return torch.from_numpy(a_mask)

def train_one_epoch(a_model, optimizer, epoch, batches):

  a_model.train()
  for batch_idx, (data, target) in enumerate(batches):
      if args['cuda']:
          data, target = data.cuda(), target.cuda()
      # Variables in Pytorch are differentiable.

      data, target = Variable(data), Variable(target)
      #This will zero out the gradients for this batch.
      optimizer.zero_grad()

      # Create DropCircuit mask
      dc_mask = make_mask(a_model.num_branches, args['dc_prob_drop'])

      output = a_model(data, dc_mask)

      # Calculate the negative log likelihood loss.
      loss = F.nll_loss(output, target)
      #dloss/dx for every Variable
      loss.backward()
      # Gradient clipping
      torch.nn.utils.clip_grad_norm_(a_model.parameters(), args['clip_level'])
      #to do a one-step update on our parameter.
      optimizer.step()
      #Print out the loss periodically.

  if args['verbose_train']:
    if epoch % args['log_interval_epoch'] == 0:
      print('Epoch: {}. Latest loss: {}.'.format(epoch, loss.data))

# Compute accuracy
# The argument (data_source) of this function can be a data_loader or a list of batches (previously extracted)
def comp_accuracy(a_model, data_source, src_num_instances):
    a_model.eval()
    a_loss = 0
    correct = 0
    preds = torch.zeros(0)
    first = True
    for a_data_in, a_data_out in data_source:
        if args['cuda']:
            a_data_in, a_data_out = a_data_in.cuda(), a_data_out.cuda()
        a_data_in, a_data_out = Variable(a_data_in), Variable(a_data_out)
        output = a_model(a_data_in)

        a_loss += F.nll_loss(output, a_data_out, reduction='sum').data # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        if first:
          preds = pred
          first = False
        else:
          preds = torch.cat((preds, pred),0)

        correct += pred.eq(a_data_out.data.view_as(pred)).long().cpu().sum()

    # Compute and return accuracy
    if type(data_source) == list:  # case: list of batches
      result = 100. * (correct.numpy()/ src_num_instances)
    else: # case: data_loader
      result = 100. * (correct.numpy()/ len(data_source.dataset))
    return result



# ==========================
# Train and test functions
# ==========================

# Compute the number of parameters in a chromose (depends on limits)
def comp_num_chrom_param(limits):
  # Num. of training parameters
  tot_train_param = 4 # lr1, lr2, lr2 prop, momentum
  # Num. of pre-branch parameters
  tot_pre_branch = 1+(6*limits['max_pre_branch_layers']) # exist-or-not, layer params.
  # Num. of branch parameters
  tot_branch = (1+(6*limits['max_branch_layers']))*limits['max_branches']
  # Num. of post-branch parameters
  tot_post_branch = 1+(6*limits['max_post_branch_layers'])

  return tot_train_param+tot_pre_branch+tot_branch+tot_post_branch

# Interpret learning rate and momentum parameters
def interp_lrm(params):
  lr1 = scale_to_range(params[0], limits['lr1_min'], limits['lr1_,max'])
  lr2 = scale_to_range(params[1], limits['lr2_min'], limits['lr2_,max'])
  if lr1 < lr2:
    temp = lr1
    lr1 = lr2
    lr2 = temp
  lr2_epoch = (np.round(params[2]*args['num_epochs_search'])).astype(int)
  a_decr = (lr1-lr2)/lr2_epoch
  a_momentum = scale_to_range(params[3], limits['moment_min'], limits['moment_max'])
  return lr1, lr2, lr2_epoch, a_momentum, a_decr

# Chromosome evaluation (more efficient than do_training)
# Function to train a specific model
# Early stopping, or returning best validation model, is not implemented
def do_eval_chrom(a_model, train_params, num_epochs):

  # Extract basic information
  lr1, lr2, lr2_epoch, a_momentum, lr_decr = train_params
  args['lr'] = lr1
  args['momentum'] = a_momentum

  optimizer = optim.SGD(a_model.parameters(), lr=args['lr'], momentum=args['momentum'])
  valid_accurs = []
  train_accurs = []
  train_start_time = time.time()
  for epoch in range(1, num_epochs + 1):

    if args['verbose_train']:
      print('Epoch {} learning rate: {}.'.format(epoch, args['lr']))

    train_one_epoch(a_model, optimizer, epoch, train_batches)

    a_train_accur = comp_accuracy(a_model, train_batches, num_train_instances)
    if args['verbose_train']:
      print('Training accuracy: {}%.'.format(a_train_accur))
    train_accurs.append(a_train_accur)

    a_valid_accur = comp_accuracy(a_model, valid_batches, num_valid_instances)
    if args['verbose_train']:
      print('Validation accuracy: {}%.'.format(a_valid_accur))
    valid_accurs.append(a_valid_accur)

    # Decrement learning rate
    if epoch < lr2_epoch:
        args['lr'] -= lr_decr
        for param_group in optimizer.param_groups:
          param_group['lr'] = args['lr']

  train_elapsed_time = time.time() - train_start_time
  print('The training process took {} seconds.'.format(train_elapsed_time))

  return a_model, valid_accurs, train_accurs

# Function to train a specific model
# Early stopping, or returning best validation model, is not implemented
def do_training(a_model, train_params, num_epochs):

  lr1, lr2, lr2_epoch, a_momentum, lr_decr = train_params
  args['lr'] = lr1
  args['momentum'] = a_momentum

  optimizer = optim.SGD(a_model.parameters(), lr=args['lr'], momentum=args['momentum'])
  best_valid_accur = 0
  best_model = type(a_model)(a_model.chromosome) # get a new instance
  valid_accurs = []
  train_accurs = []
  train_start_time = time.time()
  for epoch in range(1, num_epochs + 1):

    if args['verbose_train']:
      print('Epoch {} learning rate: {}.'.format(epoch, args['lr']))

    train_one_epoch(a_model, optimizer, epoch, train_batches)

    a_train_accur = comp_accuracy(a_model, train_batches, num_train_instances)
    if args['verbose_train']:
      print('Training accuracy: {}%.'.format(a_train_accur))
    train_accurs.append(a_train_accur)

    a_valid_accur = comp_accuracy(a_model, valid_batches, num_valid_instances)
    if args['verbose_train']:
      print('Validation accuracy: {}%.'.format(a_valid_accur))
    valid_accurs.append(a_valid_accur)
    if a_valid_accur > best_valid_accur:
      best_valid_accur = a_valid_accur
      # best_model.load_state_dict(a_model.state_dict()) # copy weights and stuff
      best_model = copy.deepcopy(a_model)

    # Decrement learning rate
    if epoch < lr2_epoch:
        args['lr'] -= lr_decr
        for param_group in optimizer.param_groups:
          param_group['lr'] = args['lr']

  train_elapsed_time = time.time() - train_start_time
  print('The training process took {} seconds.'.format(train_elapsed_time))

  if args['cuda']:
      best_model.cuda()

  return a_model, best_model, valid_accurs, train_accurs

# ================================
# Architectural search
# ================================

# Artificial Intelligence Methods students should focus on the code below.
# You should keep the neural network code unchaged. This is crucial for
# comparison purposes. In other words, focus only on modifying the architecture
# search code below.

# --- Architectural search parameters
meta = {}
meta['max_rs_iter'] = 10 # initial random search
meta['max_shc_iter'] = 20 # stochastic hill climbing iterations
meta['num_neighbours'] = 8
meta['neighbour_range'] = 0.8 # mutation rate for stochastic hill-climbing
meta['num_differential_sol'] = 8 # number of differential evolution solutions
meta['diff_lr'] = 0.05 # learning rate for differential search

meta_rs_valids = []
best_model = None
best_chromosome = None
best_model_accur = 0

list_of_chromosome = [] #population of best chromosomes being stored
backup_list_of_chromosome = [] #used in errorHandlingListChrom
new_backup_list_of_chromosome = [] #used in errorHandlingListChrom

first_neighbour = []  #for create chromosome funtion
chro_eval = 0

# Randomize the array
def randomize (arr, n):
    # Start from the last element and swap one by one.
    for i in range(n-1,0,-1):
        # Pick a random index from 0 to i
        j = random.randint(0,i-1)
        # Swap arr[i] with the element at random index
        arr[i],arr[j] = arr[j],arr[i]
    return arr

# Make sure the array in the list of chromosome which contains best chromosomes > 1 for crossover
def errorHandlingListChrom(list_chromosome):
    new_backup_list_of_chromosome = backup_list_of_chromosome [-2:]
    list_of_chromosome = new_backup_list_of_chromosome + list_chromosome
    return list_of_chromosome

# Crossover of two of the best chromosomes
def mateChrom (list_of_chromosome):
  list_of_chromosome = list_of_chromosome[-2:]
  first_best_chromosome = list_of_chromosome [-1]
  sec_best_chromosome = list_of_chromosome [0]
  length = len(first_best_chromosome)
  middle_index = length//2
  first_best_chromosome = first_best_chromosome[:middle_index]
  length = len(sec_best_chromosome)
  middle_index = length//2
  sec_best_chromosome = sec_best_chromosome[middle_index:]
  best_chromosome = np.concatenate((first_best_chromosome, sec_best_chromosome))
  return best_chromosome

# Mutation of chromosome
def mutate (arr):
    do_mutate = random.randint(1,100)
    # 30% chance of shuffling the whole position of genes
    if do_mutate < 30:
      arr = shuffle(arr, random_state=0)
    else:
      length = len(arr)
      k = 0
      while k < length:
        do_mutate = random.randint(1,100)
        #each gene has 50% chance to be swapped with random position in the array
        if  do_mutate < 50:
          # Pick a random index from 0 to i
          j = random.randint(0,375)
          # Swap arr[i] with the element at random index
          arr[k],arr[j] = arr[j],arr[k]
        k += 1
      arr = arr
    return arr

# Prepare model
def prepare_model(a_rand_chrom):

  # Initialize chromosome and model
  model = GBNDM(a_rand_chrom)

  if args['cuda']:
      model.cuda()

  # Interpret learning rates and momentum
  lr1, lr2, lr2_epoch, a_momentum, lr_decr = interp_lrm(a_rand_chrom[0:4])
  train_params = (lr1, lr2, lr2_epoch, a_momentum, lr_decr)
  args['momentum'] = a_momentum
  if args['verbose_train']:
    print('lr1: {}'.format(lr1))
    print('lr2: {}'.format(lr2))
    print('lr2_epoch: {}'.format(lr2_epoch))
    print('a_momentum: {}'.format(a_momentum))
    print('a_decr: {}'.format(a_decr))

  return model, train_params

# Start with a small random search
i = 1
rs_iter = meta['max_rs_iter']
new_chromosome_exist= 0
prev_valid_accur = 0
current_valid_accur = 0
previous_best_chromosome = gen_rand_chromosome(comp_num_chrom_param(limits))
population_chromosomes = []
best_population_chromosomes = []
worst_population_chromosomes = []

print('Initital random search ...')
while i <= rs_iter:

  if args['verbose_meta']:
    print('Search iteration {}.'.format(i))
    #print('Search iteration {}.'.format(rsi+1))

  num_chrom_param = comp_num_chrom_param(limits)

 #concantenate the best chromosome gained previously with the random chromosome
 #generated to ensure in getting even better chromosome in next evaluation
  if new_chromosome_exist == 1:
    a_rand_chrom = gen_rand_chromosome(num_chrom_param)
    concatenate_chromosome = np.concatenate((a_rand_chrom, g_new_chromosome))
    randomize_chromosome = randomize(concatenate_chromosome, len(concatenate_chromosome))
    a_rand_chrom = randomize_chromosome[:376]
  else:
    a_rand_chrom = gen_rand_chromosome(num_chrom_param)

  # --- Actual training
  model, train_params = prepare_model(a_rand_chrom)
  model, valid_accurs, train_accurs = do_eval_chrom(model, train_params, args['num_epochs_search'])
  best_valid_accur = max(valid_accurs)
  print('Best validation accuracy: {}%.'.format(best_valid_accur))

  current_valid_accur = best_valid_accur

  # Store best model
  if best_valid_accur > best_model_accur:
    best_model_accur = best_valid_accur
    best_model = model
    best_train_params = train_params
    best_chromosome = a_rand_chrom
    #creating population of best chromosomes
    list_of_chromosome.append(best_chromosome)
    best_population_chromosomes.append(best_chromosome)
    #ensuring in getting better chromosomes for next iterations
    concatenate_chromosome = np.concatenate((previous_best_chromosome, best_chromosome))
    randomize_chromosome = randomize(concatenate_chromosome, len(concatenate_chromosome))
    g_new_chromosome = randomize_chromosome[:376]
    previous_best_chromosomes = g_new_chromosome
    new_chromosome_exist = 1
  elif i < 11 and best_valid_accur <= best_model_accur:
    #increase number of iterations if the chromosome some did not do well in first 10 iterations
    rs_iter = rs_iter + 1
    #creating population of bad chromosomes to ensure premature convergence did not occur
    worst_population_chromosomes.append(a_rand_chrom)
    if current_valid_accur > prev_valid_accur:
      prev_valid_accur = current_valid_accur
      backup_list_of_chromosome.append(a_rand_chrom)
  else:
    worst_population_chromosomes.append(a_rand_chrom)
  i +=1

  meta_rs_valids.append(best_valid_accur)

#population of best chrosomes
population_chromosomes = np.array(population_chromosomes)
population_chromosomes = best_population_chromosomes + worst_population_chromosomes
population_chromosomes = population_chromosomes[:7] #7 because then it will be appended with the best chromosome

if len(list_of_chromosome) == 1:
  list_of_chromosome = errorHandlingListChrom(list_of_chromosome)

best_chromosome = mateChrom (list_of_chromosome) #crossover of list of best chromosome
best_chromosome = mutate (best_chromosome) #mutation of chromosome if probability less than 50% or 30%
best_chromosome = np.array(best_chromosome)

#population of chromosomes being crossed over and mutated with the best chromsome in the generation
i = 0
op_pop_chrom = []
while i < 7:
  op_pop_chrom = np.concatenate((population_chromosomes [i], best_chromosome))
  #crossover of current chromosome with the best chromosome
  randomize_chromosome = randomize(op_pop_chrom, len(op_pop_chrom))
  op_pop_chrom = randomize_chromosome[:376]
  #mutation
  do_mutate = random.randint(1,100)
  if do_mutate < 30:
    op_pop_chrom = shuffle(op_pop_chrom, random_state=0)
  else:
    length = len(op_pop_chrom)
    k = 0
    while k < length:
      do_mutate = random.randint(1,100)
      if  do_mutate < 50:
        # Pick a random index from 0 to i
        j = random.randint(0,375)
        # Swap arr[i] with the element at random index
        op_pop_chrom[k],op_pop_chrom[j] = op_pop_chrom[j],op_pop_chrom[k]
      k += 1
  population_chromosomes [i] = op_pop_chrom
  i += 1

population_chromosomes.append(best_chromosome)
best_chromosome = population_chromosomes

print('*****************************************************')
print('Best accuracy after initial random search: {}'.format(best_model_accur))
print('*****************************************************')

if args['verbose_meta']:
  print('Best validation errors:')
  print(meta_rs_valids)

# # --- Stochastic hill climbing

num_chrom_params = 376
chro_eval = chro_eval

# Function for creating one neighbour
def create_a_neighbour(a_chromosome, neighbour_range, num_chrom_params):
  # Create mutation vector
  mutat_vec = (np.random.rand(num_chrom_params)*neighbour_range)-(neighbour_range/2)
  # Add mutation vector
  new_chromosome = a_chromosome + mutat_vec
  # Clip
  np.clip(new_chromosome, 0, 0.99999999999, out=new_chromosome)
  return new_chromosome

# Evaluate a list of chromosomes
def eval_chromosomes(list_chromosomes,num_chrom_params):

  # best_model_accur, best_chromosome, best_model, best_train_params = best_res

  best_model_accur = 0
  best_chromosome = None
  best_model = None
  best_train_params = None

  num_chrom = len(list_chromosomes)
  mat_chrom_acur = np.zeros((num_chrom, 1+num_chrom_params))
  neighb_valid_accurs = []
  list_of_chromosome = []

  loop_eval_chrom = 1
  loop_list_chrom = 0
  diff_true = 0
  new_chromosome_exist = 0
  prev_valid_accur = 0
  previous_best_chromosome = list_chromosomes[0]
  population_chromosomes = []
  best_population_chromosomes = []
  worst_population_chromosomes = []

  #for ci, a_chrom in enumerate(list_chromosomes):
  while loop_eval_chrom <= num_chrom:
    ci = loop_eval_chrom - 1

    if args['verbose_meta']:
      print('Chromosome {} ...'.format(ci))

    # --- Actual training
    a_chrom = list_chromosomes[loop_list_chrom]

    #to combine current chromosome in the list with previously evaluated
    #chromosome to ensure diversity therefore avoiding premature convergence
    if  diff_true == 1: #otherwise use the chromosomes in the population
      if new_chromosome_exist == 1:
        concatenate_chromosome = np.concatenate((a_chrom, g_new_chromosome))
        randomize_chromosome = randomize(concatenate_chromosome, len(concatenate_chromosome))
        a_chrom = randomize_chromosome[:376]

    model, train_params = prepare_model(a_chrom)
    model, valid_accurs, train_accurs = do_eval_chrom(model, train_params, args['num_epochs_search'])
    best_valid_accur = max(valid_accurs)

    current_valid_accur = best_valid_accur

    # Store chromosome and accuracy
    mat_chrom_acur[ci,0] = best_valid_accur
    mat_chrom_acur[ci,1:] = a_chrom
    print('Best validation accuracy: {}%.'.format(best_valid_accur))
    neighb_valid_accurs.append(best_valid_accur)

    diff = best_valid_accur - best_model_accur

    if diff < 30:
      diff_true = 1
    else:
      diff_true == 0

    if best_valid_accur > best_model_accur:
      best_model_accur = best_valid_accur
      best_chromosome = a_chrom
      best_model = model
      best_train_params = train_params
      list_of_chromosome.append(best_chromosome)
      best_population_chromosomes.append(best_chromosome)
      concatenate_chromosome = np.concatenate((previous_best_chromosome, best_chromosome))
      randomize_chromosome = randomize(concatenate_chromosome, len(concatenate_chromosome))
      g_new_chromosome = randomize_chromosome[:376]
      previous_best_chromosomes = g_new_chromosome
      new_chromosome_exist = 1
      if args['verbose_meta']:
        print('*** Improving validation accuracy: {}.'.format(best_model_accur))
    elif loop_eval_chrom < num_chrom:
      concatenate_chromosome = np.concatenate((previous_best_chromosome, a_chrom))
      randomize_chromosome = randomize(concatenate_chromosome, len(concatenate_chromosome))
      g_new_chromosome = randomize_chromosome[:376]
      previous_best_chromosomes = g_new_chromosome
      m = len(best_chromosome)
      #ensure that the chromosome in next iteration is concatenated with the best chromosome
      #that is gained currently
      randomize_list = list_chromosomes[loop_list_chrom + 1] + best_chromosome
      shuffle(randomize_list, random_state=0)
      list_chromosomes[loop_list_chrom + 1], dummy_value = randomize_list[:m], randomize_list[m:]
      worst_population_chromosomes.append(a_chrom)
      if current_valid_accur > prev_valid_accur:
        prev_valid_accur = current_valid_accur
        backup_list_of_chromosome.append(a_chrom)
    else:
      worst_population_chromosomes.append(a_chrom)
      backup_list_of_chromosome.append(a_chrom)

    loop_eval_chrom += 1
    loop_list_chrom += 1

  population_chromosomes = np.array(population_chromosomes)

  population_chromosomes = best_population_chromosomes + worst_population_chromosomes

  if len(list_of_chromosome) == 1:
    list_of_chromosome = errorHandlingListChrom(list_of_chromosome)

  best_chromosome = mateChrom (list_of_chromosome)

  best_chromosome = mutate (best_chromosome)

  best_chromosome = np.array(best_chromosome)

  i = 0
  op_pop_chrom = []
  while i < 7:
    op_pop_chrom = np.concatenate((population_chromosomes [i], best_chromosome))
    #mutation
    randomize_chromosome = randomize(op_pop_chrom, len(op_pop_chrom))
    op_pop_chrom = randomize_chromosome[:376]
    #mating
    do_mutate = random.randint(1,100)
    if do_mutate < 30:
      op_pop_chrom = shuffle(op_pop_chrom, random_state=0)
    else:
      length = len(op_pop_chrom)
      k = 0
      while k < length:
        do_mutate = random.randint(1,100)
        if  do_mutate < 50:
          # Pick a random index from 0 to i
          j = random.randint(0,375)
          # Swap arr[i] with the element at random index
          op_pop_chrom[k],op_pop_chrom[j] = op_pop_chrom[j],op_pop_chrom[k]
          k += 1
    population_chromosomes [i] = op_pop_chrom
    i += 1

  population_chromosomes.append(best_chromosome)
  best_chromosome = population_chromosomes

  best_res = (best_model_accur, best_chromosome, best_model, best_train_params)
  return best_res, mat_chrom_acur


# Function for creating a list of neighbours
def create_neighbours(a_chromosome, meta, num_chrom_params):
  neighbours = []
  # Scan through number of neighbours
  i = 1
  num_neighbours = 15
  #a_chromsome has multiple chromsomes so 'while loop' is used to iterate them
  while i < num_neighbours:
    # Create neighbour
    #the if else below is to make sure that the best chromosomes is produced
    if i < 9:
      m = i - 1
      chosen_chromosome = a_chromosome [m]
    else:
      m = i - 7
      chosen_chromosome = a_chromosome [m]
    a_neighb = create_a_neighbour(chosen_chromosome, meta['neighbour_range'], num_chrom_params)
    # Append neighbour
    neighbours.append(a_neighb)
    #Elimitate 0s and 1s with other values from the array
    if len(neighbours) == 1:
      first_neighbour = neighbours[0]
      k = 0
      rand_n = random.randint(1,375)
      while k < 376:
        if first_neighbour[k] == 0 or first_neighbour[k] == 1:
          first_neighbour[k] = first_neighbour[rand_n]
        k += 1
    else:
      #first_neighbour = neighbours[0]
      other_neighbour = neighbours[i-1]
      k = 0
      rand_n = random.randint(1,375)
      while k < 376:
        if other_neighbour[k] == 0 or other_neighbour[k] == 1:
          other_neighbour[k] = other_neighbour[rand_n]
        k += 1
    i+=1
  #chose neigbours position 4 to 12 in list
  neighbours = neighbours[4:12]

  return neighbours

# Simple differential search
def do_diff_chrom_v1(mat_chrom_accur, num_new_sol):

  # Initialize new chromosomes
  num_chrom = mat_chrom_accur.shape[0]
  if num_new_sol >= num_chrom:
    num_new_sol = num_chrom - 1
  new_chromosomes = []

  # Sort the array of chromosomes based on the first column (contains accur.)
  mat_chrom_accur = mat_chrom_accur[(-mat_chrom_accur[:,0]).argsort()]

  #Extract the best and worst chromosome
  best_chrom = mat_chrom_accur[0,1:]
  worst_chrom = mat_chrom_accur[-1,1:]

  # Scan through new solutions
  i = 0
  while i < num_new_sol + 1:

    # Extract next best chrom

    # Initialisation
    if i < num_new_sol:
      next_best_chrom = mat_chrom_accur[1+i,1:]
    else:
      next_best_chrom = mat_chrom_accur[-1,1:]

    # Mutation done by combining next_best_chrom with worst_chrom
    next_best_chrom = np.concatenate((next_best_chrom, worst_chrom))
    next_best_chrom = randomize(next_best_chrom, len(next_best_chrom))
    next_best_chrom = next_best_chrom[:376]

    # Compute differential
    a_diff = best_chrom - next_best_chrom
    # Add differential whilst applying a learning rate
    a_new_chrom = best_chrom + (meta['diff_lr']*a_diff)
    np.clip(a_new_chrom, 0, 0.99999999999, out=a_new_chrom)

    # Store new solution
    new_chromosomes.append(a_new_chrom)
    #Elimitate 0s and 1s with better values which is from the best chromosome values
    if len(new_chromosomes) == 1:
      first_neighbour = new_chromosomes[0]
      k = 0
      rand_n = random.randint(1,375)
      while k < 376:
        if first_neighbour[k] == 0 or first_neighbour[k] == 1:
          first_neighbour[k] = first_neighbour[rand_n]
        k += 1
    else:
      other_neighbour = new_chromosomes[i-1]
      k = 0
      rand_n = random.randint(1,375)
      while k < 376:
        if other_neighbour[k] == 0 or other_neighbour[k] == 1:
          other_neighbour[k] = other_neighbour[rand_n]
        k += 1
    i += 1


  # Recombination the population of chromsomes
  i = 0
  while i < 8:
    # Selection
    if i == 0:
      #combining with the last chromosomes
      op_pop_chrom = np.concatenate((new_chromosomes [0], new_chromosomes[-1]))
    else:
      #combining with the previous chromosomes
      op_pop_chrom = np.concatenate((new_chromosomes [i], new_chromosomes[i-1]))
    # Crossover
    randomize_chromosome = randomize(op_pop_chrom, len(op_pop_chrom))
    op_pop_chrom = randomize_chromosome[:376]
    # Mutation
    do_mutate = random.randint(1,100)
    if do_mutate < 30:
      op_pop_chrom = shuffle(op_pop_chrom, random_state=0)
    else:
      length = len(op_pop_chrom)
      k = 0
      while k < length:
        do_mutate = random.randint(1,100)
        if  do_mutate < 50:
          # Pick a random index from 0 to i
          j = random.randint(0,375)
          # Swap arr[i] with the element at random index
          op_pop_chrom[k],op_pop_chrom[j] = op_pop_chrom[j],op_pop_chrom[k]
          k += 1
    new_chromosomes [i] = op_pop_chrom
    i += 1

  return new_chromosomes


# Architectural search iterations

best_res = (best_model_accur, best_chromosome, best_model, best_train_params)

meta_start_time = time.time()
for shci in range(meta['max_shc_iter']):

  best_model_accur, best_chromosome, best_model, best_train_params = best_res

  if args['verbose_meta']:
    print('======================================')
    print('Stochastic hill-climbing iteration {}.'.format(shci))
    print('======================================')
    print('Best accuracy so far: {}'.format(best_model_accur))
    print('======================================')
  # --- Create a set of stochastic neighbours from the current best model
  chrom_neighbors = create_neighbours(best_chromosome, meta, num_chrom_params)
  # Test validation accuracies of neighbours
  new_res, mat_chrom_acur = eval_chromosomes(chrom_neighbors,num_chrom_params)
  if new_res[0] > best_res[0]:
    best_res = new_res
  print('***********************************************')
  print('Best accuracy after random mutation: {}'.format(new_res[0]))
  print('***********************************************')

  # --- Simple differential search
  print('***** Differential Search *********************')
  diff_chromosomes = do_diff_chrom_v1(mat_chrom_acur, meta['num_differential_sol'])
  new_res, mat_chrom_acur = eval_chromosomes(diff_chromosomes,num_chrom_params)
  if new_res[0] > best_res[0]:
    best_res = new_res
  print('***********************************************')
  print('Best accuracy after differential search: {}'.format(new_res[0]))
  print('***********************************************')

meta_elapsed_time = time.time() - meta_start_time
if args['verbose_meta']:
  print('=====================================================')
  print('Architectural optimization total time: {}.'.format(meta_elapsed_time))
  print('=====================================================')


# ==========================
# Test final model / Visualize predictions
# ==========================

def final_test(a_model):
    a_model.eval()
    test_loss = 0
    correct = 0
    test_preds = torch.zeros(0)
    first = True
    for test_data_in, test_data_out in test_loader:

        if args['cuda']:
            test_data_in, test_data_out = test_data_in.cuda(), test_data_out.cuda()

        test_data_in, test_data_out = Variable(test_data_in), Variable(test_data_out)
        output = a_model(test_data_in)
        test_loss += F.nll_loss(output, test_data_out, reduction='sum').data # sum up batch loss

        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        if first:
          test_preds = pred
          first = False
        else:
          test_preds = torch.cat((test_preds, pred),0)

        correct += pred.eq(test_data_out.data.view_as(pred)).long().cpu().sum()

    # Print test accuracy
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy (at final epoch): {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), accuracy))

    return accuracy

# Final visualization
print('======================================')
print('Best accuracy so far: {}'.format(best_res[0]))
print('======================================')
print('Computing the final test ...')
best_model_accur, best_chromosome, best_model, best_train_params = best_res
final_model, best_valid_model, valid_accurs, train_accurs = do_training(best_model, best_train_params, args['num_epochs_test'])
print('=====================================')
print('Training accuracies')
print('=====================================')
print(train_accurs)
print('=====================================')
print('Best training parameters')
print('=====================================')
print(best_train_params)
print('=====================================')
print('Best model')
print('=====================================')
print(best_valid_model)
print('=====================================')
print('Test accuracies')
print('=====================================')
print('Model with best validation accuracy: ')
accur_valid = final_test(best_valid_model)
print('Model at the end of training: ')
accur_final = final_test(final_model)

max_accur = int(max(accur_valid, accur_final))

# --- Saving the best chromosome as a csv file
if args['save_best_chrom']:

  print('Saving the best chromosome in the root directory (My Drive) ...')

  from datetime import datetime
  from numpy import asarray
  from numpy import savetxt
  import numpy as np
  from google.colab import drive

  drive.mount('/content/gdrive/')

  def get_date_time_str():
    now = datetime.now() # current date and time
    return now.strftime("%d%m%Y_%H%M")

  # Create filename
  path = '/content/gdrive/My Drive/'
  filename = 'chrom_' + get_date_time_str() + version + str(max_accur)
  savetxt(path+filename, best_chromosome, delimiter=',')
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 87833844.75it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 40979598.72it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 29569244.24it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 21697640.97it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Data extraction trial 0.
# Initital random search ...
# Search iteration 1.
# The training process took 2.0275518894195557 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 2.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# The training process took 1.0934922695159912 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 3.
# The training process took 0.9415497779846191 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 4.
# The training process took 0.6077790260314941 seconds.
# Best validation accuracy: 11.4%.
# Search iteration 5.
# <ipython-input-1-6a45b57cbb93>:783: RuntimeWarning: divide by zero encountered in double_scalars
#   a_decr = (lr1-lr2)/lr2_epoch
# The training process took 0.4137382507324219 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 6.
# The training process took 0.685020923614502 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 7.
# The training process took 0.7255783081054688 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 8.
# The training process took 0.4772021770477295 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 9.
# The training process took 0.5202291011810303 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 10.
# The training process took 0.7710764408111572 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 11.
# The training process took 0.5702817440032959 seconds.
# Best validation accuracy: 11.4%.
# Search iteration 12.
# The training process took 0.6743381023406982 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 13.
# The training process took 0.588623046875 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 14.
# The training process took 0.47980594635009766 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 15.
# The training process took 0.6363403797149658 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 16.
# The training process took 0.4664137363433838 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 17.
# The training process took 0.573075532913208 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 18.
# The training process took 0.7826168537139893 seconds.
# Best validation accuracy: 12.4%.
# Search iteration 19.
# The training process took 0.2420668601989746 seconds.
# Best validation accuracy: 12.4%.
# *****************************************************
# Best accuracy after initial random search: 12.4
# *****************************************************
# Best validation errors:
# [12.4, 12.4, 12.4, 11.4, 12.4, 12.4, 12.4, 12.4, 12.4, 12.4, 11.4, 12.4, 12.4, 12.4, 12.4, 12.4, 12.4, 12.4, 12.4]
# ======================================
# Stochastic hill-climbing iteration 0.
# ======================================
# Best accuracy so far: 12.4
# ======================================
# Chromosome 0 ...
# The training process took 0.18622899055480957 seconds.
# Best validation accuracy: 21.5%.
# *** Improving validation accuracy: 21.5.
# Chromosome 1 ...
# The training process took 0.27368879318237305 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.17356443405151367 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.1922624111175537 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.18854427337646484 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.14533376693725586 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.346210241317749 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.23334908485412598 seconds.
# Best validation accuracy: 12.6%.
# ***********************************************
# Best accuracy after random mutation: 21.5
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.31817126274108887 seconds.
# Best validation accuracy: 21.099999999999998%.
# *** Improving validation accuracy: 21.099999999999998.
# Chromosome 1 ...
# The training process took 0.30475854873657227 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.37337636947631836 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.38118886947631836 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.2301032543182373 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.33789825439453125 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.3333170413970947 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.23197031021118164 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 21.099999999999998
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 1.
# ======================================
# Best accuracy so far: 21.5
# ======================================
# Chromosome 0 ...
# The training process took 0.279310941696167 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.15664434432983398 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.1666254997253418 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.1443171501159668 seconds.
# Best validation accuracy: 17.7%.
# *** Improving validation accuracy: 17.7.
# Chromosome 4 ...
# The training process took 0.18368148803710938 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.1337754726409912 seconds.
# Best validation accuracy: 52.2%.
# *** Improving validation accuracy: 52.2.
# Chromosome 6 ...
# The training process took 0.18858027458190918 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.13417935371398926 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 52.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.18863320350646973 seconds.
# Best validation accuracy: 11.1%.
# *** Improving validation accuracy: 11.1.
# Chromosome 1 ...
# The training process took 0.17108154296875 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 2 ...
# The training process took 0.16498494148254395 seconds.
# Best validation accuracy: 32.1%.
# *** Improving validation accuracy: 32.1.
# Chromosome 3 ...
# The training process took 0.15664982795715332 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.11981940269470215 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.15894293785095215 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.08688783645629883 seconds.
# Best validation accuracy: 13.100000000000001%.
# Chromosome 7 ...
# The training process took 0.09046173095703125 seconds.
# Best validation accuracy: 29.5%.
# ***********************************************
# Best accuracy after differential search: 32.1
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 2.
# ======================================
# Best accuracy so far: 52.2
# ======================================
# Chromosome 0 ...
# The training process took 0.1357579231262207 seconds.
# Best validation accuracy: 65.8%.
# *** Improving validation accuracy: 65.8.
# Chromosome 1 ...
# The training process took 0.20997858047485352 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.11131715774536133 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.0855405330657959 seconds.
# Best validation accuracy: 67.80000000000001%.
# *** Improving validation accuracy: 67.80000000000001.
# Chromosome 4 ...
# The training process took 0.1434192657470703 seconds.
# Best validation accuracy: 15.4%.
# Chromosome 5 ...
# The training process took 0.13068151473999023 seconds.
# Best validation accuracy: 59.9%.
# Chromosome 6 ...
# The training process took 0.08857989311218262 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.12232661247253418 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 67.80000000000001
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.11475706100463867 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.08618950843811035 seconds.
# Best validation accuracy: 32.1%.
# *** Improving validation accuracy: 32.1.
# Chromosome 2 ...
# The training process took 0.1507704257965088 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.10946369171142578 seconds.
# Best validation accuracy: 68.60000000000001%.
# *** Improving validation accuracy: 68.60000000000001.
# Chromosome 4 ...
# The training process took 0.08805680274963379 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.10005521774291992 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.10200834274291992 seconds.
# Best validation accuracy: 24.6%.
# Chromosome 7 ...
# The training process took 0.08895444869995117 seconds.
# Best validation accuracy: 62.0%.
# ***********************************************
# Best accuracy after differential search: 68.60000000000001
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 3.
# ======================================
# Best accuracy so far: 68.60000000000001
# ======================================
# Chromosome 0 ...
# The training process took 0.11138176918029785 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.12595653533935547 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.10636138916015625 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.11278247833251953 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.10066819190979004 seconds.
# Best validation accuracy: 26.0%.
# *** Improving validation accuracy: 26.0.
# Chromosome 5 ...
# The training process took 0.11968874931335449 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.09272408485412598 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.08396530151367188 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 26.0
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.11845231056213379 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1107790470123291 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.07265877723693848 seconds.
# Best validation accuracy: 42.5%.
# *** Improving validation accuracy: 42.5.
# Chromosome 3 ...
# The training process took 0.09364819526672363 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.10097241401672363 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.07913851737976074 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.0780947208404541 seconds.
# Best validation accuracy: 64.0%.
# *** Improving validation accuracy: 64.0.
# Chromosome 7 ...
# The training process took 0.08127140998840332 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 64.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 4.
# ======================================
# Best accuracy so far: 68.60000000000001
# ======================================
# Chromosome 0 ...
# The training process took 0.10888433456420898 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1352245807647705 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.10509037971496582 seconds.
# Best validation accuracy: 70.3%.
# *** Improving validation accuracy: 70.3.
# Chromosome 3 ...
# The training process took 0.09393787384033203 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.06891942024230957 seconds.
# Best validation accuracy: 68.2%.
# Chromosome 5 ...
# The training process took 0.09576249122619629 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.08161139488220215 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.08615994453430176 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 70.3
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.1352708339691162 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.12106013298034668 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.08278441429138184 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.0758824348449707 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.08697390556335449 seconds.
# Best validation accuracy: 22.3%.
# *** Improving validation accuracy: 22.3.
# Chromosome 5 ...
# The training process took 0.09281587600708008 seconds.
# Best validation accuracy: 69.6%.
# *** Improving validation accuracy: 69.6.
# Chromosome 6 ...
# The training process took 0.08725547790527344 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.09144854545593262 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 69.6
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 5.
# ======================================
# Best accuracy so far: 70.3
# ======================================
# Chromosome 0 ...
# The training process took 0.132643461227417 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1392505168914795 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.08171892166137695 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.07646036148071289 seconds.
# Best validation accuracy: 73.5%.
# *** Improving validation accuracy: 73.5.
# Chromosome 4 ...
# The training process took 0.09330320358276367 seconds.
# Best validation accuracy: 43.9%.
# Chromosome 5 ...
# The training process took 0.13088202476501465 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.10793662071228027 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.09291672706604004 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 73.5
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.08163642883300781 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.10966014862060547 seconds.
# Best validation accuracy: 30.099999999999998%.
# *** Improving validation accuracy: 30.099999999999998.
# Chromosome 2 ...
# The training process took 0.08178591728210449 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.0815420150756836 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.07553458213806152 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.08423042297363281 seconds.
# Best validation accuracy: 68.89999999999999%.
# *** Improving validation accuracy: 68.89999999999999.
# Chromosome 6 ...
# The training process took 0.08635497093200684 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.08231043815612793 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 68.89999999999999
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 6.
# ======================================
# Best accuracy so far: 73.5
# ======================================
# Chromosome 0 ...
# The training process took 0.17155790328979492 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1031956672668457 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.0963737964630127 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.17829370498657227 seconds.
# Best validation accuracy: 51.1%.
# *** Improving validation accuracy: 51.1.
# Chromosome 4 ...
# The training process took 0.21301794052124023 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.15454506874084473 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.15171384811401367 seconds.
# Best validation accuracy: 18.5%.
# Chromosome 7 ...
# The training process took 0.09532451629638672 seconds.
# Best validation accuracy: 70.7%.
# *** Improving validation accuracy: 70.7.
# ***********************************************
# Best accuracy after random mutation: 70.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.10547685623168945 seconds.
# Best validation accuracy: 70.8%.
# *** Improving validation accuracy: 70.8.
# Chromosome 1 ...
# The training process took 0.11219906806945801 seconds.
# Best validation accuracy: 39.6%.
# Chromosome 2 ...
# The training process took 0.11116909980773926 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.09554338455200195 seconds.
# Best validation accuracy: 11.4%.
# Chromosome 4 ...
# The training process took 0.08556413650512695 seconds.
# Best validation accuracy: 72.0%.
# *** Improving validation accuracy: 72.0.
# Chromosome 5 ...
# The training process took 0.11511111259460449 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.10401797294616699 seconds.
# Best validation accuracy: 18.5%.
# Chromosome 7 ...
# The training process took 0.10201907157897949 seconds.
# Best validation accuracy: 59.4%.
# ***********************************************
# Best accuracy after differential search: 72.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 7.
# ======================================
# Best accuracy so far: 73.5
# ======================================
# Chromosome 0 ...
# The training process took 0.19378304481506348 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.18010473251342773 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.17052841186523438 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.1083219051361084 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.10419249534606934 seconds.
# Best validation accuracy: 22.3%.
# *** Improving validation accuracy: 22.3.
# Chromosome 5 ...
# The training process took 0.12658977508544922 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.13955068588256836 seconds.
# Best validation accuracy: 63.7%.
# *** Improving validation accuracy: 63.7.
# Chromosome 7 ...
# The training process took 0.12977266311645508 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 63.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.1376640796661377 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.12971067428588867 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.14096403121948242 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.08287167549133301 seconds.
# Best validation accuracy: 23.1%.
# *** Improving validation accuracy: 23.1.
# Chromosome 4 ...
# The training process took 0.0997762680053711 seconds.
# Best validation accuracy: 16.900000000000002%.
# Chromosome 5 ...
# The training process took 0.1145782470703125 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.0918278694152832 seconds.
# Best validation accuracy: 48.699999999999996%.
# *** Improving validation accuracy: 48.699999999999996.
# Chromosome 7 ...
# The training process took 0.11960792541503906 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 48.699999999999996
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 8.
# ======================================
# Best accuracy so far: 73.5
# ======================================
# Chromosome 0 ...
# The training process took 0.15317010879516602 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1610870361328125 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.09793806076049805 seconds.
# Best validation accuracy: 73.6%.
# *** Improving validation accuracy: 73.6.
# Chromosome 3 ...
# The training process took 0.13268375396728516 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.08148431777954102 seconds.
# Best validation accuracy: 23.400000000000002%.
# Chromosome 5 ...
# The training process took 0.11435985565185547 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.09745001792907715 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.12386250495910645 seconds.
# Best validation accuracy: 58.4%.
# ***********************************************
# Best accuracy after random mutation: 73.6
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.12246060371398926 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.0849447250366211 seconds.
# Best validation accuracy: 11.4%.
# Chromosome 2 ...
# The training process took 0.085693359375 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.08945870399475098 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.08805727958679199 seconds.
# Best validation accuracy: 32.1%.
# *** Improving validation accuracy: 32.1.
# Chromosome 5 ...
# The training process took 0.09406208992004395 seconds.
# Best validation accuracy: 32.5%.
# *** Improving validation accuracy: 32.5.
# Chromosome 6 ...
# The training process took 0.11066102981567383 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.08460164070129395 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 32.5
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 9.
# ======================================
# Best accuracy so far: 73.6
# ======================================
# Chromosome 0 ...
# The training process took 0.10667181015014648 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.16967535018920898 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.13136506080627441 seconds.
# Best validation accuracy: 27.1%.
# *** Improving validation accuracy: 27.1.
# Chromosome 3 ...
# The training process took 0.1287379264831543 seconds.
# Best validation accuracy: 28.4%.
# *** Improving validation accuracy: 28.4.
# Chromosome 4 ...
# The training process took 0.15769338607788086 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.08875107765197754 seconds.
# Best validation accuracy: 14.7%.
# Chromosome 6 ...
# The training process took 0.14603686332702637 seconds.
# Best validation accuracy: 36.5%.
# *** Improving validation accuracy: 36.5.
# Chromosome 7 ...
# The training process took 0.12897634506225586 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 36.5
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.09851574897766113 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.09079575538635254 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.1164708137512207 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.07267045974731445 seconds.
# Best validation accuracy: 66.4%.
# *** Improving validation accuracy: 66.4.
# Chromosome 4 ...
# The training process took 0.09314084053039551 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.0840451717376709 seconds.
# Best validation accuracy: 65.8%.
# Chromosome 6 ...
# The training process took 0.07140445709228516 seconds.
# Best validation accuracy: 73.6%.
# *** Improving validation accuracy: 73.6.
# Chromosome 7 ...
# The training process took 0.08097600936889648 seconds.
# Best validation accuracy: 68.7%.
# ***********************************************
# Best accuracy after differential search: 73.6
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 10.
# ======================================
# Best accuracy so far: 73.6
# ======================================
# Chromosome 0 ...
# The training process took 0.16443538665771484 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.13518667221069336 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.0859682559967041 seconds.
# Best validation accuracy: 50.6%.
# *** Improving validation accuracy: 50.6.
# Chromosome 3 ...
# The training process took 0.13964390754699707 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.07759428024291992 seconds.
# Best validation accuracy: 75.2%.
# *** Improving validation accuracy: 75.2.
# Chromosome 5 ...
# The training process took 0.1612563133239746 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.07686114311218262 seconds.
# Best validation accuracy: 61.0%.
# Chromosome 7 ...
# The training process took 0.08742403984069824 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 75.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.10017871856689453 seconds.
# Best validation accuracy: 66.5%.
# *** Improving validation accuracy: 66.5.
# Chromosome 1 ...
# The training process took 0.1121683120727539 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.07041049003601074 seconds.
# Best validation accuracy: 74.1%.
# *** Improving validation accuracy: 74.1.
# Chromosome 3 ...
# The training process took 0.09393620491027832 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.08331608772277832 seconds.
# Best validation accuracy: 44.4%.
# Chromosome 5 ...
# The training process took 0.08099126815795898 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.08371090888977051 seconds.
# Best validation accuracy: 72.39999999999999%.
# Chromosome 7 ...
# The training process took 0.09858036041259766 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 74.1
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 11.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.12230682373046875 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.13613200187683105 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.10526561737060547 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.08547544479370117 seconds.
# Best validation accuracy: 70.7%.
# *** Improving validation accuracy: 70.7.
# Chromosome 4 ...
# The training process took 0.14520645141601562 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.08622074127197266 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.07760787010192871 seconds.
# Best validation accuracy: 34.599999999999994%.
# Chromosome 7 ...
# The training process took 0.1150970458984375 seconds.
# Best validation accuracy: 58.4%.
# ***********************************************
# Best accuracy after random mutation: 70.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.12778377532958984 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.11641335487365723 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.12914252281188965 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.11157107353210449 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.07629251480102539 seconds.
# Best validation accuracy: 11.4%.
# Chromosome 5 ...
# The training process took 0.07944560050964355 seconds.
# Best validation accuracy: 22.2%.
# *** Improving validation accuracy: 22.2.
# Chromosome 6 ...
# The training process took 0.08553481101989746 seconds.
# Best validation accuracy: 20.4%.
# Chromosome 7 ...
# The training process took 0.08006429672241211 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 22.2
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 12.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.11805558204650879 seconds.
# Best validation accuracy: 11.1%.
# *** Improving validation accuracy: 11.1.
# Chromosome 1 ...
# The training process took 0.1247255802154541 seconds.
# Best validation accuracy: 73.8%.
# *** Improving validation accuracy: 73.8.
# Chromosome 2 ...
# The training process took 0.12467479705810547 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.13460969924926758 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.0805366039276123 seconds.
# Best validation accuracy: 70.6%.
# Chromosome 5 ...
# The training process took 0.1009819507598877 seconds.
# Best validation accuracy: 11.4%.
# Chromosome 6 ...
# The training process took 0.08907794952392578 seconds.
# Best validation accuracy: 70.8%.
# Chromosome 7 ...
# The training process took 0.1229696273803711 seconds.
# Best validation accuracy: 11.1%.
# ***********************************************
# Best accuracy after random mutation: 73.8
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.1701979637145996 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.15172648429870605 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.12345480918884277 seconds.
# Best validation accuracy: 26.0%.
# *** Improving validation accuracy: 26.0.
# Chromosome 3 ...
# The training process took 0.11629796028137207 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.10217642784118652 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.08481383323669434 seconds.
# Best validation accuracy: 15.2%.
# Chromosome 6 ...
# The training process took 0.10294961929321289 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.1316978931427002 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 26.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 13.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.18997430801391602 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1600813865661621 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.09997749328613281 seconds.
# Best validation accuracy: 74.9%.
# *** Improving validation accuracy: 74.9.
# Chromosome 3 ...
# The training process took 0.17923593521118164 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.1712193489074707 seconds.
# Best validation accuracy: 53.6%.
# Chromosome 5 ...
# The training process took 0.16054916381835938 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.11719322204589844 seconds.
# Best validation accuracy: 63.0%.
# Chromosome 7 ...
# The training process took 0.09591269493103027 seconds.
# Best validation accuracy: 73.0%.
# ***********************************************
# Best accuracy after random mutation: 74.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.15773653984069824 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.1597578525543213 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.1507554054260254 seconds.
# Best validation accuracy: 57.699999999999996%.
# *** Improving validation accuracy: 57.699999999999996.
# Chromosome 3 ...
# The training process took 0.1495673656463623 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.1508774757385254 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.0958256721496582 seconds.
# Best validation accuracy: 69.5%.
# *** Improving validation accuracy: 69.5.
# Chromosome 6 ...
# The training process took 0.1390705108642578 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.14687085151672363 seconds.
# Best validation accuracy: 21.9%.
# ***********************************************
# Best accuracy after differential search: 69.5
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 14.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.19979238510131836 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.17591619491577148 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.15244269371032715 seconds.
# Best validation accuracy: 36.4%.
# *** Improving validation accuracy: 36.4.
# Chromosome 3 ...
# The training process took 0.15616846084594727 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.11689090728759766 seconds.
# Best validation accuracy: 75.0%.
# *** Improving validation accuracy: 75.0.
# Chromosome 5 ...
# The training process took 0.19661784172058105 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.1346898078918457 seconds.
# Best validation accuracy: 10.2%.
# Chromosome 7 ...
# The training process took 0.07955026626586914 seconds.
# Best validation accuracy: 19.400000000000002%.
# ***********************************************
# Best accuracy after random mutation: 75.0
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.1020040512084961 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.08726692199707031 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.0814967155456543 seconds.
# Best validation accuracy: 71.0%.
# *** Improving validation accuracy: 71.0.
# Chromosome 3 ...
# The training process took 0.0836184024810791 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.08952617645263672 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.07226753234863281 seconds.
# Best validation accuracy: 63.3%.
# Chromosome 6 ...
# The training process took 0.09067964553833008 seconds.
# Best validation accuracy: 64.7%.
# Chromosome 7 ...
# The training process took 0.08945775032043457 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 71.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 15.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.14439606666564941 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.10178041458129883 seconds.
# Best validation accuracy: 11.4%.
# Chromosome 2 ...
# The training process took 0.1157982349395752 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.08937859535217285 seconds.
# Best validation accuracy: 71.8%.
# *** Improving validation accuracy: 71.8.
# Chromosome 4 ...
# The training process took 0.13106250762939453 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.12304425239562988 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.09416866302490234 seconds.
# Best validation accuracy: 23.799999999999997%.
# Chromosome 7 ...
# The training process took 0.09159135818481445 seconds.
# Best validation accuracy: 71.89999999999999%.
# *** Improving validation accuracy: 71.89999999999999.
# ***********************************************
# Best accuracy after random mutation: 71.89999999999999
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.10143256187438965 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.0946660041809082 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.08936285972595215 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.07799673080444336 seconds.
# Best validation accuracy: 73.1%.
# *** Improving validation accuracy: 73.1.
# Chromosome 4 ...
# The training process took 0.12203335762023926 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.10494041442871094 seconds.
# Best validation accuracy: 45.4%.
# Chromosome 6 ...
# The training process took 0.07763290405273438 seconds.
# Best validation accuracy: 70.89999999999999%.
# Chromosome 7 ...
# The training process took 0.10275530815124512 seconds.
# Best validation accuracy: 61.4%.
# ***********************************************
# Best accuracy after differential search: 73.1
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 16.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.13272404670715332 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.15059542655944824 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.1176605224609375 seconds.
# Best validation accuracy: 50.0%.
# *** Improving validation accuracy: 50.0.
# Chromosome 3 ...
# The training process took 0.14432668685913086 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.11568260192871094 seconds.
# Best validation accuracy: 24.0%.
# Chromosome 5 ...
# The training process took 0.09000825881958008 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.09533953666687012 seconds.
# Best validation accuracy: 16.6%.
# Chromosome 7 ...
# The training process took 0.0798487663269043 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after random mutation: 50.0
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.1205291748046875 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.15148711204528809 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.14028000831604004 seconds.
# Best validation accuracy: 70.39999999999999%.
# *** Improving validation accuracy: 70.39999999999999.
# Chromosome 3 ...
# The training process took 0.15245318412780762 seconds.
# Best validation accuracy: 71.2%.
# *** Improving validation accuracy: 71.2.
# Chromosome 4 ...
# The training process took 0.12822842597961426 seconds.
# Best validation accuracy: 14.299999999999999%.
# Chromosome 5 ...
# The training process took 0.07965230941772461 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.08821964263916016 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.10785603523254395 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 71.2
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 17.
# ======================================
# Best accuracy so far: 75.2
# ======================================
# Chromosome 0 ...
# The training process took 0.15468811988830566 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.14290881156921387 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.09163451194763184 seconds.
# Best validation accuracy: 73.1%.
# *** Improving validation accuracy: 73.1.
# Chromosome 3 ...
# The training process took 0.08782100677490234 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.11217498779296875 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.09610652923583984 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.10900497436523438 seconds.
# Best validation accuracy: 52.7%.
# Chromosome 7 ...
# The training process took 0.0959324836730957 seconds.
# Best validation accuracy: 27.500000000000004%.
# ***********************************************
# Best accuracy after random mutation: 73.1
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.10482001304626465 seconds.
# Best validation accuracy: 75.8%.
# *** Improving validation accuracy: 75.8.
# Chromosome 1 ...
# The training process took 0.091949462890625 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.1065220832824707 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.09225296974182129 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 4 ...
# The training process took 0.10665035247802734 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.11607694625854492 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 6 ...
# The training process took 0.1073904037475586 seconds.
# Best validation accuracy: 65.0%.
# Chromosome 7 ...
# The training process took 0.07290840148925781 seconds.
# Best validation accuracy: 72.39999999999999%.
# ***********************************************
# Best accuracy after differential search: 75.8
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 18.
# ======================================
# Best accuracy so far: 75.8
# ======================================
# Chromosome 0 ...
# The training process took 0.11634016036987305 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.09550070762634277 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.09610271453857422 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.08154702186584473 seconds.
# Best validation accuracy: 62.2%.
# *** Improving validation accuracy: 62.2.
# Chromosome 4 ...
# The training process took 0.09669947624206543 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.10463595390319824 seconds.
# Best validation accuracy: 42.1%.
# Chromosome 6 ...
# The training process took 0.08647799491882324 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.08530378341674805 seconds.
# Best validation accuracy: 40.6%.
# ***********************************************
# Best accuracy after random mutation: 62.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.10180091857910156 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.10291028022766113 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.11438298225402832 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.0794227123260498 seconds.
# Best validation accuracy: 22.2%.
# *** Improving validation accuracy: 22.2.
# Chromosome 4 ...
# The training process took 0.12986993789672852 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.07004499435424805 seconds.
# Best validation accuracy: 66.3%.
# *** Improving validation accuracy: 66.3.
# Chromosome 6 ...
# The training process took 0.09223580360412598 seconds.
# Best validation accuracy: 11.1%.
# Chromosome 7 ...
# The training process took 0.0962378978729248 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 66.3
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 19.
# ======================================
# Best accuracy so far: 75.8
# ======================================
# Chromosome 0 ...
# The training process took 0.08576440811157227 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.12215995788574219 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 2 ...
# The training process took 0.08092164993286133 seconds.
# Best validation accuracy: 70.8%.
# *** Improving validation accuracy: 70.8.
# Chromosome 3 ...
# The training process took 0.09300875663757324 seconds.
# Best validation accuracy: 70.39999999999999%.
# Chromosome 4 ...
# The training process took 0.10612726211547852 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 5 ...
# The training process took 0.0715336799621582 seconds.
# Best validation accuracy: 68.10000000000001%.
# Chromosome 6 ...
# The training process took 0.08569955825805664 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 7 ...
# The training process took 0.08169174194335938 seconds.
# Best validation accuracy: 69.8%.
# ***********************************************
# Best accuracy after random mutation: 70.8
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.09564733505249023 seconds.
# Best validation accuracy: 12.4%.
# *** Improving validation accuracy: 12.4.
# Chromosome 1 ...
# The training process took 0.10776376724243164 seconds.
# Best validation accuracy: 44.0%.
# *** Improving validation accuracy: 44.0.
# Chromosome 2 ...
# The training process took 0.11953043937683105 seconds.
# Best validation accuracy: 12.4%.
# Chromosome 3 ...
# The training process took 0.10225462913513184 seconds.
# Best validation accuracy: 41.9%.
# Chromosome 4 ...
# The training process took 0.0962364673614502 seconds.
# Best validation accuracy: 43.6%.
# Chromosome 5 ...
# The training process took 0.08098602294921875 seconds.
# Best validation accuracy: 29.4%.
# Chromosome 6 ...
# The training process took 0.0955810546875 seconds.
# Best validation accuracy: 57.99999999999999%.
# *** Improving validation accuracy: 57.99999999999999.
# Chromosome 7 ...
# The training process took 0.08641839027404785 seconds.
# Best validation accuracy: 12.4%.
# ***********************************************
# Best accuracy after differential search: 57.99999999999999
# ***********************************************
# =====================================================
# Architectural optimization total time: 42.023133993148804.
# =====================================================
# ======================================
# Best accuracy so far: 75.8
# ======================================
# Computing the final test ...
# The training process took 11.1739661693573 seconds.
# =====================================
# Training accuracies
# =====================================
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 10 ...
# =====================================
# Best training parameters
# =====================================
# (1.99999999998001, 1.9000499999810094, 10, 0.99999999999001, 0.009994999999900056)
# =====================================
# Best model
# =====================================
# GBNDM(
#   (pre_branch_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=99, bias=True)
#       (1): Tanh()
#     )
#     (1-3): 3 x Identity()
#   )
#   (branches): ModuleList(
#     (0): ModuleList(
#       (0): Identity()
#       (1): Elem_Scaling_1D()
#       (2-4): 3 x Identity()
#     )
#   )
#   (post_branch_layers): ModuleList(
#     (0): Sequential(
#       (0): Elem_Scaling_1D()
#       (1): SELU()
#     )
#     (1-3): 3 x Identity()
#   )
#   (final_layer): Linear(in_features=99, out_features=10, bias=True)
# )
# =====================================
# Test accuracies
# =====================================
# Model with best validation accuracy:
#
# Test set: Average loss: 0.8789, Accuracy (at final epoch): 7679/10000 (77%)
#
# Model at the end of training:
#
# Test set: Average loss: 8.7469, Accuracy (at final epoch): 5031/10000 (50%)
#
# Saving the best chromosome in the root directory (My Drive) ...
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-6a45b57cbb93> in <cell line: 1501>()
#    1509   from google.colab import drive
#    1510
# -> 1511   drive.mount('/content/gdrive/')
#    1512
#    1513   def get_date_time_str():
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
